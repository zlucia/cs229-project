# %%
import numpy as np
import pandas as pd
from importlib import reload
import util
reload(util)
data = util.FontData
# %matplotlib inline

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
data.load()
# Out:
# Loading embeddings...done
# Loading geometric + semantic vectors...done
# Loading images...done

# %%
pca = PCA(n_components=2)

colors = {'display': 'red',
          'handwriting': 'orange',
          'monospace': 'green',
          'sans-serif': 'blue',
          'serif': 'black'}
categories = [colors[c] for c in data.get_all_category('train')]
marker_size = 12

# %%
embeddings = data.get_all_embedding('train+val')
embeddings_pca = pca.fit_transform(embeddings)

# %%
plt.scatter(embeddings_pca[:,0], embeddings_pca[:, 1], color=categories, s=marker_size)
plt.savefig("data_exploration.png", dpi=200)
plt.show()

# %%
geometric = data.get_all_geometric('train+val')
geometric_pca = pca.fit_transform(geometric)

# %%
plt.scatter(geometric_pca[:,0], geometric_pca[:, 1], color=categories, s=marker_size)

# %%
semantic = data.get_all_semantic('train+val')
semantic_pca = pca.fit_transform(semantic)

# %%
plt.scatter(semantic_pca[:,0], semantic_pca[:, 1],  color=categories, s=marker_size)

# %%
images = data.get_all_image('train+val')
images = images.reshape(images.shape[0], -1)
images_pca = pca.fit_transform(images)

# %%
plt.scatter(images_pca[:,0], images_pca[:, 1], color=categories, s=marker_size)
